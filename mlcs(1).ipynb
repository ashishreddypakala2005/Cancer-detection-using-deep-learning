# %% [markdown]
# <a href="https://colab.research.google.com/github/ashishreddypakala2005/Cancer-detection-using-deep-learning/blob/main/mlcs(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Installation of Required Libraries**

# %%
# !pip install tensorflow opencv-python matplotlib

# %% [markdown]
# **Importing Required Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.model_selection import train_test_split

# %%
from google.colab import files
files.upload()

# %% [markdown]
# **Checking Uploaded Files**

# %%
import os
print(os.listdir())

# %% [markdown]
# **Extracting Dataset**

# %%
import zipfile

zip_ref = zipfile.ZipFile("dataset.zip", 'r')
zip_ref.extractall("/content/dataset")
zip_ref.close()

# %% [markdown]
# **Verifying Dataset Structure**

# %%
import os
print(os.listdir("/content/dataset"))

# %% [markdown]
# **Data Loading and Preprocessing**

# %%
import numpy as np
import os
import cv2

IMG_SIZE = 128

data = []
labels = []

for folder in ['yes', 'no']:
    path = os.path.join('/content/dataset', folder)

    label = 1 if folder == 'yes' else 0

    for img in os.listdir(path):
        try:
            img_path = os.path.join(path, img)
            image = cv2.imread(img_path)
            image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
            data.append(image)
            labels.append(label)
        except:
            pass

data = np.array(data) / 255.0
labels = np.array(labels)

print("Data loaded:", len(data))

# %% [markdown]
# **Splitting Dataset into Training and Testing Sets**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    data, labels, test_size=0.2, random_state=42
)

print("Train size:", len(X_train))
print("Test size:", len(X_test))

# %% [markdown]
# **Splitting Dataset into Training and Testing Sets**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(32, (3,3), activation='relu', input_shape=(128,128,3)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128, (3,3), activation='relu'))   # NEW layer
model.add(MaxPooling2D(2,2))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))   # NEW (prevents overfitting)

model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **Evaluating Model Performance**

# %% [markdown]
# **Dataset Splitting**

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# **Training the Model**

# %%
history = model.fit(
    X_train, y_train,
    epochs=20,
    validation_data=(X_test, y_test)
)

# %% [markdown]
# **Model Evaluation**

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print("Final Accuracy:", accuracy)

# %% [markdown]
# **Model Accuracy Visualization**

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title("Model Accuracy")
plt.show()

# %% [markdown]
# **Upload Image**

# %% [markdown]
# **Uploading Test Image**

# %%
from google.colab import files
uploaded = files.upload()

# %%
import os
print(os.listdir())

# %% [markdown]
# **Retrieving Uploaded Image Name**

# %%
img = cv2.imread('/content/tumour.jpg')

# %% [markdown]
# **Reading Test Image**

# %%
from google.colab import files
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 🔹 Step 1: Upload image
uploaded = files.upload()

# Get file name
img_name = list(uploaded.keys())[0]

# 🔹 Step 2: Read image
img = cv2.imread(img_name)

if img is None:
    print("Error loading image")
else:
    # 🔹 Step 3: Show image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title("Uploaded Image")
    plt.axis('off')
    plt.show()

    # 🔹 Step 4: Preprocess
    img_resized = cv2.resize(img, (128,128))
    img_resized = img_resized / 255.0
    img_resized = img_resized.reshape(1,128,128,3)

    # 🔹 Step 5: Prediction
    prediction = model.predict(img_resized)
    confidence = float(prediction[0][0])

    # 🔹 Step 6: Output
    if confidence > 0.5:
        print("🧠 Cancer Detected")
        print(f"Confidence: {confidence*100:.2f}%")
    else:
        print("✅ Normal")
        print(f"Confidence: {(1-confidence)*100:.2f}%")

# %% [markdown]
# **Retrieving Uploaded Image Name**

# %% [markdown]
# **bold text**

# %%
from google.colab import files
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 🔹 Step 1: Upload image
uploaded = files.upload()

# Get file name
img_name = list(uploaded.keys())[0]

# 🔹 Step 2: Read image
img = cv2.imread(img_name)

if img is None:
    print("Error loading image")
else:
    # 🔹 Step 3: Show image
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title("Uploaded Image")
    plt.axis('off')
    plt.show()

    # 🔹 Step 4: Preprocess
    img_resized = cv2.resize(img, (128,128))
    img_resized = img_resized / 255.0
    img_resized = img_resized.reshape(1,128,128,3)

    # 🔹 Step 5: Prediction
    prediction = model.predict(img_resized)
    confidence = float(prediction[0][0])

    # 🔹 Step 6: Output
    if confidence > 0.5:
        print("🧠 Cancer Detected")
        print(f"Confidence: {confidence*100:.2f}%")
    else:
        print("✅ Normal")
        print(f"Confidence: {(1-confidence)*100:.2f}%")
